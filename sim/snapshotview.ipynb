# %%
import argparse
import os
import math
import hoomd
import hoomd.md
import numpy as np
import time

import gsd.hoomd

# %%
traj = gsd.hoomd.open('/home/cli428/vitrimer/data/test/vitrimerPaper/NVT/V4Test/snapshotSeed/snapshotSeed_rho0.500000_NVT.gsd')

# %%
traj.particles
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 traj.particles
#
# AttributeError: 'HOOMDTrajectory' object has no attribute 'particles'

# %%
device = hoomd.device.CPU()
sim = hoomd.simulation.Simulation(device=device)

sim.create_state_from_gsd(
    filename='/home/cli428/vitrimer/data/test/vitrimerPaper/NVT/V4Test/snapshotSeed/snapshotSeed_rho0.500000_NVT.gsd',
    frame=1   # or -1 for last frame
)

# %%
test=sim.state.get_snapshot()

# %%
test.particles.typeid[:25]
# Out:
# array([0, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 1, 3, 1, 1, 2,
#        1, 1, 2], dtype=uint32)
